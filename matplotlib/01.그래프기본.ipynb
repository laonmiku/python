# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' #맑은 고딕
matplotlib.rcParams['font.size'] = 15 #글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False #한글 폰트 사용 시 마이너스 글자가 깨지는 현상을 해결

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x, y)
plt.title('선그래프')
plt.xlabel('X축', color='red', loc='right')
plt.ylabel('Y축', color='#00AA00', loc='top')
plt.show()

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist #사용가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Sans',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'cmr10',
#  'cmsy10',
#  'cmtt10',
#  'DejaVu Serif Display',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'STIXSizeFiveSym',
#  'STIXSizeTwoSym',
#  'cmb10',
#  'cmss10',
#  'DejaVu Sans',
#  'cmex10',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'STIXSizeOneSym',
#  'DejaVu Sans Display',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'STIXSizeFourSym',
#  'STIXSizeOneSym',
#  'DejaVu Serif',
#  'cmmi10',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'DejaVu Serif',
#  'Californian FB',
#  'Elephant',
#  'Microsoft PhagsPa',
#  'Yu Gothic',
#  'Franklin Gothic Demi Cond',
#  'Segoe MDL2 Assets',
#  'Mistral',
#  'Perpetua',
#  'Lucida Sans',
#  'Georgia',
#  'Bradley Hand ITC',
#  'Onyx',
#  'Times New Roman',
# ...

# %%
x = [1, 2, 3, 4]
y = [50, 60, 70, 80]

# %%
plt.figure(dpi=200)
plt.plot(x, y, linewidth=1, marker='o', 
         ms=10, linestyle='-.', color='g',
         mec='red',mfc='yellow')
plt.xlabel('공부시간')
plt.ylabel('점수')
for idx, txt in enumerate(y):
  plt.text(x[idx], y[idx]+0.7, txt, ha='center', color='b')
plt.show()
