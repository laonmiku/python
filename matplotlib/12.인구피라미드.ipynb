# %%
import pandas as pd

# %%
df_m=pd.read_excel('data/201108.xlsx', 
                   skiprows=3,index_col='행정기관',
                   usecols='B, E:Y')
df_m.head(1)
# Out:
# c:\Users\KOSMO\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#            0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국    1,195,951  1,233,465  1,663,534  1,890,498  1,667,705  1,844,651
#
#          30~34세     35~39세     40~44세     45~49세  ...     55~59세     60~64세  \
# 행정기관                                              ...
# 전국    2,048,038  2,178,901  2,335,456  2,165,327  ...  1,556,649  1,129,517
#
#        65~69세   70~74세   75~79세   80~84세  85~89세  90~94세 95~99세 100세 이상
# 행정기관
# 전국    883,074  701,439  419,877  186,554  75,904  22,020  4,651   2,607
#
# [1 rows x 21 columns]

# %%
df_m.iloc[0]=df_m.iloc[0].str.replace(',','').astype(int)
df_m.head(1)
# Out:
#          0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세   35~39세  \
# 행정기관
# 전국    1195951  1233465  1663534  1890498  1667705  1844651  2048038  2178901
#
#        40~44세   45~49세  ...   55~59세   60~64세  65~69세  70~74세  75~79세  80~84세  \
# 행정기관                    ...
# 전국    2335456  2165327  ...  1556649  1129517  883074  701439  419877  186554
#
#      85~89세 90~94세 95~99세 100세 이상
# 행정기관
# 전국    75904  22020   4651    2607
#
# [1 rows x 21 columns]

# %%
df_w = pd.read_excel('data/201108.xlsx',
                     skiprows=3,
                     index_col='행정기관',
                     usecols='B, AB:AV')
df_w.head(1)
# Out:
# c:\Users\KOSMO\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#          0~4세.1     5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국    1,125,896  1,141,102  1,524,143  1,668,412  1,506,676  1,737,973
#
#        30~34세.1   35~39세.1   40~44세.1   45~49세.1  ...   55~59세.1   60~64세.1  \
# 행정기관                                              ...
# 전국    1,963,094  2,092,175  2,257,824  2,052,553  ...  1,573,948  1,182,335
#
#        65~69세.1 70~74세.1 75~79세.1 80~84세.1 85~89세.1 90~94세.1 95~99세.1  \
# 행정기관
# 전국    1,013,184  914,270  684,870  416,098  202,997   70,111   18,637
#
#      100세 이상.1
# 행정기관
# 전국       8,695
#
# [1 rows x 21 columns]

# %%
df_w.iloc[0]=df_w.iloc[0].str.replace(',','').astype(int)
df_w.head(1)
# Out:
#        0~4세.1   5~9세.1 10~14세.1 15~19세.1 20~24세.1 25~29세.1 30~34세.1 35~39세.1  \
# 행정기관
# 전국    1125896  1141102  1524143  1668412  1506676  1737973  1963094  2092175
#
#      40~44세.1 45~49세.1  ... 55~59세.1 60~64세.1 65~69세.1 70~74세.1 75~79세.1  \
# 행정기관                    ...
# 전국    2257824  2052553  ...  1573948  1182335  1013184   914270   684870
#
#      80~84세.1 85~89세.1 90~94세.1 95~99세.1 100세 이상.1
# 행정기관
# 전국     416098   202997    70111    18637      8695
#
# [1 rows x 21 columns]

# %%
df_m.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns
# Out:
# Index(['0~4세.1', '5~9세.1', '10~14세.1', '15~19세.1', '20~24세.1', '25~29세.1',
#        '30~34세.1', '35~39세.1', '40~44세.1', '45~49세.1', '50~54세.1', '55~59세.1',
#        '60~64세.1', '65~69세.1', '70~74세.1', '75~79세.1', '80~84세.1', '85~89세.1',
#        '90~94세.1', '95~99세.1', '100세 이상.1'],
#       dtype='object')

# %%
df_w.columns = df_m.columns

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' #맑은 고딕
matplotlib.rcParams['font.size'] = 15 #글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False #한글 폰트 사용 시 마이너스 글자가 깨지는 현상을 해결

# %%
plt.figure(figsize=(10, 7))
plt.barh(df_m.columns, -df_m.iloc[0]//1000)
plt.barh(df_w.columns, df_w.iloc[0]//1000)
plt.title('2011 연령별 인구분포')
plt.savefig('data/2011.png')
plt.show()

# %%
df_m=pd.read_excel('data/202407.xlsx', 
                   skiprows=3,index_col='행정기관',
                   usecols='B, E:Y')
df_m.head(1)
# Out:
# c:\Users\KOSMO\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#          0~4세     5~9세     10~14세     15~19세     20~24세     25~29세     30~34세  \
# 행정기관
# 전국    659,954  986,513  1,195,022  1,185,850  1,408,133  1,748,364  1,817,952
#
#          35~39세     40~44세     45~49세  ...     55~59세     60~64세     65~69세  \
# 행정기관                                   ...
# 전국    1,622,003  2,021,792  1,942,815  ...  2,138,774  2,096,981  1,716,169
#
#          70~74세   75~79세   80~84세   85~89세  90~94세  95~99세 100세 이상
# 행정기관
# 전국    1,096,071  783,469  526,625  242,361  62,946  10,567   1,568
#
# [1 rows x 21 columns]

# %%
df_m.iloc[0]=df_m.iloc[0].str.replace(',','').astype(int)
df_m.head(1)
# Out:
#         0~4세    5~9세   10~14세   15~19세   20~24세   25~29세   30~34세   35~39세  \
# 행정기관
# 전국    659954  986513  1195022  1185850  1408133  1748364  1817952  1622003
#
#        40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  75~79세  \
# 행정기관                    ...
# 전국    2021792  1942815  ...  2138774  2096981  1716169  1096071  783469
#
#       80~84세  85~89세 90~94세 95~99세 100세 이상
# 행정기관
# 전국    526625  242361  62946  10567    1568
#
# [1 rows x 21 columns]

# %%
df_w = pd.read_excel('data/202407.xlsx',
                     skiprows=3,
                     index_col='행정기관',
                     usecols='B, AB:AV')
df_w.head(1)
# Out:
# c:\Users\KOSMO\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#        0~4세.1   5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1   30~34세.1  \
# 행정기관
# 전국    629,033  937,900  1,133,127  1,116,537  1,302,905  1,595,036  1,636,873
#
#        35~39세.1   40~44세.1   45~49세.1  ...   55~59세.1   60~64세.1   65~69세.1  \
# 행정기관                                   ...
# 전국    1,522,282  1,946,879  1,886,277  ...  2,121,580  2,119,737  1,810,521
#
#        70~74세.1 75~79세.1 80~84세.1 85~89세.1 90~94세.1 95~99세.1 100세 이상.1
# 행정기관
# 전국    1,236,870  968,348  813,818  504,307  196,939   46,769     7,120
#
# [1 rows x 21 columns]

# %%
df_w.iloc[0]=df_w.iloc[0].str.replace(',','').astype(int)
df_w.head(1)
# Out:
#       0~4세.1  5~9세.1 10~14세.1 15~19세.1 20~24세.1 25~29세.1 30~34세.1 35~39세.1  \
# 행정기관
# 전국    629033  937900  1133127  1116537  1302905  1595036  1636873  1522282
#
#      40~44세.1 45~49세.1  ... 55~59세.1 60~64세.1 65~69세.1 70~74세.1 75~79세.1  \
# 행정기관                    ...
# 전국    1946879  1886277  ...  2121580  2119737  1810521  1236870   968348
#
#      80~84세.1 85~89세.1 90~94세.1 95~99세.1 100세 이상.1
# 행정기관
# 전국     813818   504307   196939    46769      7120
#
# [1 rows x 21 columns]

# %%
df_w.columns=df_m.columns

# %%
df_w.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 7))
plt.barh(df_m.columns, -df_m.iloc[0]//1000)
plt.barh(df_w.columns, df_w.iloc[0]//1000)
plt.title('2024 연령별 인구분포')
plt.savefig('data/2024.png')
plt.show()
