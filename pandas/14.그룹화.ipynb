# %%
import pandas as pd
df = pd.read_excel('data/score.xlsx', index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df1=df[['이름','사회']][3:]
df1
# Out:
#        이름  사회
# 지원번호
# 4번    서태웅  80
# 5번    강백호  10
# 6번    변덕규  80
# 7번    황태산  35
# 8번    윤대협  95

# %%
df.groupby('학교').get_group('능남고')
# Out:
#        이름   학교    키   국어   영어  수학  과학  사회    SW특기
# 지원번호
# 6번    변덕규  능남고  202   80  100  95  85  80       C
# 7번    황태산  능남고  188   55   65  45  40  35  PYTHON
# 8번    윤대협  능남고  190  100   85  90  95  95      C#

# %%
df.groupby('학교').size()['북산고']
# Out:
# np.int64(5)

# %%
df.groupby('학교').size()
# Out:
# 학교
# 능남고    3
# 북산고    5
# dtype: int64

# %%
df.groupby('학교')['키'].mean()
# Out:
# 학교
# 능남고    193.333333
# 북산고    184.800000
# Name: 키, dtype: float64

# %%
df.groupby('학교')[['국어','영어','수학']].mean()
# Out:
#             국어         영어         수학
# 학교
# 능남고  78.333333  83.333333  76.666667
# 북산고  53.000000  55.000000  60.000000

# %%
df['학년'] = [3,3,3,1,1,3,2,2]
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기  학년
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python   3
# 2번    정대만  북산고  184   40   35   50  55  25        Java   3
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript   3
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN   1
# 5번    강백호  북산고  188   15   20   10  35  10         NaN   1
# 6번    변덕규  능남고  202   80  100   95  85  80           C   3
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON   2
# 8번    윤대협  능남고  190  100   85   90  95  95          C#   2

# %%
df.groupby(['학교', '학년']).size()
# Out:
# 학교   학년
# 능남고  2     2
#      3     1
# 북산고  1     2
#      3     3
# dtype: int64

# %%
df.groupby(['학교', '학년'])[['국어','영어','수학']].mean()
# Out:
#           국어     영어         수학
# 학교  학년
# 능남고 2   77.5   75.0  67.500000
#     3   80.0  100.0  95.000000
# 북산고 1   27.5   40.0  40.000000
#     3   70.0   65.0  73.333333

# %%
df.groupby('학년')['키'].mean()
# Out:
# 학년
# 1    187.50
# 2    189.00
# 3    187.75
# Name: 키, dtype: float64

# %%
df.groupby('학년')[['키','국어','수학']].mean().sort_values('수학', ascending=False)
# Out:
#          키    국어     수학
# 학년
# 3   187.75  72.5  78.75
# 2   189.00  77.5  67.50
# 1   187.50  27.5  40.00

# %%
df.groupby(['학교','학년']).sum()
# Out:
#                이름    키   국어   영어   수학   과학   사회                  SW특기
# 학교  학년
# 능남고 2      황태산윤대협  378  155  150  135  135  130              PYTHONC#
#     3         변덕규  202   80  100   95   85   80                     C
# 북산고 1      서태웅강백호  375   55   80   80  110   90                     0
#     3   채치수정대만송태섭  549  210  195  220  230  185  PythonJavaJavascript

# %%
df.groupby('학교')[['이름', 'SW특기']].count()
# Out:
#      이름  SW특기
# 학교
# 능남고   3     3
# 북산고   5     3

# %%
df.groupby(['학교','학년'])[['이름','SW특기']].count()
# Out:
#         이름  SW특기
# 학교  학년
# 능남고 2    2     2
#     3    1     1
# 북산고 1    2     0
#     3    3     3

# %%
school = df.groupby(['학교'])
school['학년'].value_counts(normalize=True).loc['북산고']
# Out:
# 학년
# 3    0.6
# 1    0.4
# Name: proportion, dtype: float64

# %%
df.groupby(['학교'])[['국어','영어','수학']].mean()
# Out:
#           국어     영어         수학
# 학교  학년
# 능남고 2   77.5   75.0  67.500000
#     3   80.0  100.0  95.000000
# 북산고 1   27.5   40.0  40.000000
#     3   70.0   65.0  73.333333

# %%
df.groupby(['학교'])['키'].mean()
# Out:
# 학교
# 능남고    193.333333
# 북산고    184.800000
# Name: 키, dtype: float64

# %%
import pandas as pd
df = pd.read_csv('data/bbs.csv', index_col='bid')
df = df.groupby('writer')['title'].count()
df = df.to_frame()
# Out:
#         title
# writer
# blue       66
# red       127

# %%
df
# Out:
#         title
# writer
# blue       66
# red       127

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['SW특기'] = df['SW특기'].str.capitalize()
df['SW특기'].fillna('없음', inplace=True)
df
# Out:
# C:\Users\KOSMO\AppData\Local\Temp\ipykernel_14400\428929252.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['SW특기'].fillna('없음', inplace=True)
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80          없음
# 5번    강백호  북산고  188   15   20   10  35  10          없음
# ...

# %%
df2=df.groupby('SW특기')['SW특기'].count()
df2 = df2.to_frame()
df2
# Out:
#             SW특기
# SW특기
# C              1
# C#             1
# Java           1
# Javascript     1
# Python         2
# 없음             2

# %%
# Out:
# Empty DataFrame
# Columns: [이름, 학교, 키, 국어, 영어, 수학, 과학, 사회, SW특기]
# Index: []
