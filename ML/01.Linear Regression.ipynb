# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('data/LinearRegressionData.csv')
dataset.head()
# Out:
#    hour  score
# 0   0.5     10
# 1   1.2      8
# 2   1.8     14
# 3   2.4     26
# 4   2.6     22

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
X, y
# Out:
# (array([[ 0.5],
#         [ 1.2],
#         [ 1.8],
#         [ 2.4],
#         [ 2.6],
#         [ 3.2],
#         [ 3.9],
#         [ 4.4],
#         [ 4.5],
#         [ 5. ],
#         [ 5.3],
#         [ 5.8],
#         [ 6. ],
#         [ 6.1],
#         [ 6.2],
#         [ 6.9],
#         [ 7.2],
#         [ 8.4],
#         [ 8.6],
#         [10. ]]),
#  array([ 10,   8,  14,  26,  22,  30,  42,  48,  38,  58,  60,  72,  62,
#          68,  72,  58,  76,  86,  90, 100], dtype=int64))

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X)
y_pred, y
# Out:
# (array([  5.00336377,  12.31395163,  18.58016979,  24.84638795,
#          26.93512734,  33.20134551,  40.51193337,  45.73378184,
#          46.77815153,  52.        ,  55.13310908,  60.35495755,
#          62.44369694,  63.48806663,  64.53243633,  71.84302419,
#          74.97613327,  87.5085696 ,  89.59730899, 104.2184847 ]),
#  array([ 10,   8,  14,  26,  22,  30,  42,  48,  38,  58,  60,  72,  62,
#          68,  72,  58,  76,  86,  90, 100], dtype=int64))

# %%
plt.scatter(X, y, color='blue')
plt.plot(X, y_pred, color='green')
plt.xlabel('hours')
plt.ylabel('score')
plt.show()

# %%
reg.predict([[9]])
# Out:
# array([93.77478776])

# %%
reg.predict([[9], [8], [5]])
# Out:
# array([93.77478776, 83.33109082, 52.        ])

# %%
m = reg.coef_
b = reg.intercept_
y = m * 5 + b
y
# Out:
# array([52.])

# %%
dataset = pd.read_csv('data/LinearRegressionData.csv')

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
X, y
# Out:
# (array([[ 0.5],
#         [ 1.2],
#         [ 1.8],
#         [ 2.4],
#         [ 2.6],
#         [ 3.2],
#         [ 3.9],
#         [ 4.4],
#         [ 4.5],
#         [ 5. ],
#         [ 5.3],
#         [ 5.8],
#         [ 6. ],
#         [ 6.1],
#         [ 6.2],
#         [ 6.9],
#         [ 7.2],
#         [ 8.4],
#         [ 8.6],
#         [10. ]]),
#  array([ 10,   8,  14,  26,  22,  30,  42,  48,  38,  58,  60,  72,  62,
#          68,  72,  58,  76,  86,  90, 100], dtype=int64))

# %%
reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
reg.predict([[3.2]])
# Out:
# array([33.20134551])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train, len(X_train), y_train, len(y_train)
# Out:
# (array([[5.3],
#         [8.4],
#         [3.9],
#         [6.1],
#         [2.6],
#         [1.8],
#         [3.2],
#         [6.2],
#         [5. ],
#         [4.4],
#         [7.2],
#         [5.8],
#         [2.4],
#         [0.5],
#         [6.9],
#         [6. ]]),
#  16,
#  array([60, 86, 42, 68, 22, 14, 30, 72, 58, 48, 76, 72, 26, 10, 58, 62],
#        dtype=int64),
#  16)

# %%
X_test, len(X_test), y_test, len(y_test)
# Out:
# (array([[ 8.6],
#         [ 1.2],
#         [10. ],
#         [ 4.5]]),
#  4,
#  array([ 90,   8, 100,  38], dtype=int64),
#  4)

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_train, y_train, color='blue')
plt.plot(X_train, reg.predict(X_train), color='green')
plt.title('Score by hours(train Data)')
plt.xlabel('hours')
plt.ylabel('score')
plt.show()

# %%
from sklearn.linear_model import SGDRegressor
sr = SGDRegressor()
sr.fit(X_train, y_train)
# Out:
# SGDRegressor()

# %%
plt.scatter(X_train, y_train, color='blue')
plt.plot(X_train, sr.predict(X_train), color='green')
plt.title('Score by hours(train Data: SGD)')
plt.xlabel('hours')
plt.ylabel('score')
plt.show()

# %%
sr.coef_, reg.coef_
# Out:
# (array([10.15635708]), array([10.49161294]))

# %%
sr.score(X_train, y_train), reg.score(X_train, y_train)
# Out:
# (0.934365212918486, 0.9356663661221668)

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_train, reg.predict(X_train), color='green')
plt.title('Score by hours(train Data)')
plt.xlabel('hours')
plt.ylabel('score')
plt.show()

# %%
sr = SGDRegressor(max_iter=500, eta0=0.0001, random_state=0)
sr.fit(X_train, y_train)
# Out:
# c:\Users\KOSMO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1616: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# SGDRegressor(eta0=0.0001, max_iter=500, random_state=0)

# %%
plt.scatter(X_train, y_train, color='blue')
plt.plot(X_train, sr.predict(X_train), color='green')
plt.title('Score by hours(train Data: SGD)')
plt.xlabel('hours')
plt.ylabel('score')
plt.show()

# %%
reg.coef_, m
# Out:
# (array([10.49161294]), array([10.44369694]))

# %%
reg.intercept_, b
# Out:
# (0.6115562905169369, -0.218484702867201)

# %%
reg.score(X_train, y_train)
# Out:
# 0.9356663661221668

# %%
reg.score(X_test, y_test)
# Out:
# 0.9727616474310156
