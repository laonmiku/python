# %%
import pandas as pd

# %%
dataset = pd.read_csv('data/MultipleLinearRegressionData.csv')
dataset.head()
# Out:
#    hour  absent    place  score
# 0   1.8       2     Cafe     14
# 1   0.5       3     Home     10
# 2   1.2       4  Library      8
# 3   2.4       0     Cafe     26
# 4   2.6       2     Home     22

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
X, y, len(y)
# Out:
# (array([[1.8, 2, 'Cafe'],
#         [0.5, 3, 'Home'],
#         [1.2, 4, 'Library'],
#         [2.4, 0, 'Cafe'],
#         [2.6, 2, 'Home'],
#         [3.2, 0, 'Home'],
#         [3.9, 0, 'Library'],
#         [4.4, 0, 'Library'],
#         [4.5, 5, 'Home'],
#         [5.0, 1, 'Cafe'],
#         [5.3, 2, 'Cafe'],
#         [5.8, 0, 'Cafe'],
#         [6.0, 3, 'Library'],
#         [6.1, 1, 'Cafe'],
#         [6.2, 1, 'Library'],
#         [6.9, 4, 'Home'],
#         [7.2, 2, 'Cafe'],
#         [8.4, 1, 'Home'],
#         [8.6, 1, 'Library'],
#         [10.0, 0, 'Library']], dtype=object),
#  array([ 14,  10,   8,  26,  22,  30,  42,  48,  38,  58,  60,  72,  62,
#          68,  72,  58,  76,  86,  90, 100], dtype=int64),
#  20)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(drop='first'),[2])],
                       remainder='passthrough')
X = ct.fit_transform(X)
X
# Out:
# array([[0.0, 0.0, 1.8, 2],
#        [1.0, 0.0, 0.5, 3],
#        [0.0, 1.0, 1.2, 4],
#        [0.0, 0.0, 2.4, 0],
#        [1.0, 0.0, 2.6, 2],
#        [1.0, 0.0, 3.2, 0],
#        [0.0, 1.0, 3.9, 0],
#        [0.0, 1.0, 4.4, 0],
#        [1.0, 0.0, 4.5, 5],
#        [0.0, 0.0, 5.0, 1],
#        [0.0, 0.0, 5.3, 2],
#        [0.0, 0.0, 5.8, 0],
#        [0.0, 1.0, 6.0, 3],
#        [0.0, 0.0, 6.1, 1],
#        [0.0, 1.0, 6.2, 1],
#        [1.0, 0.0, 6.9, 4],
#        [0.0, 0.0, 7.2, 2],
#        [1.0, 0.0, 8.4, 1],
#        [0.0, 1.0, 8.6, 1],
#        [0.0, 1.0, 10.0, 0]], dtype=object)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(X)
y_pred
# Out:
# array([ 21.62883572,   0.81787026,   9.71877502,  30.91713157,
#         23.71826154,  33.00655738,  43.50890284,  48.58008155,
#         38.18441854,  55.68582015,  57.12708668,  65.40114679,
#         60.00353132,  66.84241331,  65.2348842 ,  64.12751703,
#         76.39756577,  84.14537525,  89.576542  , 105.37728308])

# %%
reg.coef_
# Out:
# array([-6.02446012, -2.62176486, 10.14235742, -1.6014407 ])

# %%
reg.score(X, y)
# Out:
# 0.9746103464822871

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.2, random_state=0)

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)
X_test, y_pred, y_test
# Out:
# (array([[0.0, 1.0, 8.6, 1],
#         [1.0, 0.0, 0.5, 3],
#         [0.0, 1.0, 10.0, 0],
#         [1.0, 0.0, 4.5, 5]], dtype=object),
#  array([ 95.82903623,  -7.74003913, 113.92988958,  32.74420877]),
#  array([ 90,  10, 100,  38], dtype=int64))

# %%
reg.score(X_train, y_train)
# Out:
# 0.984935188566178

# %%
reg.score(X_test, y_test)
# Out:
# 0.8959781475745251

# %%
reg.predict([[0, 0, 9, 1]])
# Out:
# array([101.12379268])

# %%
reg.predict([[0, 0, 9, 0]])
# Out:
# array([103.43636125])

# %%
reg.predict([[1, 0, 9, 0]])
# Out:
# array([95.05510984])

# %%
reg.predict([[0, 1, 9, 0]])
# Out:
# array([102.65254331])
